# %% [markdown]
# <a href="https://colab.research.google.com/github/kkousar/fmml_projects-and-labs/blob/main/FMML_Course_Lab_3module8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-09 06:03:48--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   131MB/s    in 0.5s
#
# 2022-06-09 06:03:54 (131 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 4822   1512.02011v2  Using deep neural nets as function approximato...    cs
# 12287  1711.03560v1  We develop SHOPPER, a sequential probabilistic...  stat
# 10841  1502.01493v1  This paper presents an original approach for j...  stat
# 18684   1108.6208v1  In this work a stand-alone preprocessor for SA...    cs
# 32081   1205.2664v1  We present a modular approach to reinforcement...    cs
# ...             ...                                                ...   ...
# 13995  1704.02191v2  We propose a new way to self-adjust the mutati...    cs
# 37849   0811.4167v3  We propose a penalized orthogonal-components r...  stat
# 724    cs/0410004v1  Recurrent neural networks are often used for l...    cs
# 4928   1703.01327v1  Unifying seemingly disparate algorithmic ideas...    cs
# 17611  1712.09405v1  Many Natural Language Processing applications ...    cs
#
#                                                    title  year  \
# 4822   How to Discount Deep Reinforcement Learning: T...  2015
# 12287  SHOPPER: A Probabilistic Model of Consumer Cho...  2017
# 10841  A mixture Cox-Logistic model for feature selec...  2015
# 18684        Coprocessor - a Standalone SAT Preprocessor  2011
# 32081  A Bayesian Sampling Approach to Exploration in...  2012
# ...                                                  ...   ...
# 13995  The (1+$λ$) Evolutionary Algorithm with Self-A...  2017
# 37849  Penalized Orthogonal-Components Regression for...  2008
# 724    Applying Policy Iteration for Training Recurre...  2004
# 4928   Multi-step Reinforcement Learning: A Unifying ...  2017
# 17611  Advances in Pre-Training Distributed Word Repr...  2017
#
#                                                 keywords
# 4822   [approximator, reinforcement, approaching, com...
# 12287  [sequential, probabilistic, interpretable, com...
# 10841  [classifying, subgroups, generalized, conditio...
# 18684  [preprocessor, presented, preprocessing, techn...
# 32081  [reinforcement, representation, uncertainty, e...
# ...                                                  ...
# 13995  [population, evolutionary, algorithms, offspri...
# 37849  [penalized, orthogonal, components, regression...
# 724    [recurrent, assumptions, minimization, nonline...
# 4928   [seemingly, disparate, algorithmic, performing...
# 17611  [processing, applications, representations, es...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 4822     [approximator, reinforcement, approaching, com...
# 12287    [sequential, probabilistic, interpretable, com...
# 10841    [classifying, subgroups, generalized, conditio...
# 18684    [preprocessor, presented, preprocessing, techn...
# 32081    [reinforcement, representation, uncertainty, e...
#                                ...
# 22907    [decomposition, variables, assumption, suffici...
# 10416    [majorization, minimization, algorithms, itera...
# 39192    [stabilization, important, requisite, integrat...
# 37907    [covariance, regularization, graphical, regula...
# 8235     [information, retrieval, objectives, reconstru...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8735 words.
# Out of those 4506 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ad86ab25-92ec-4e3e-96c1-3ac9fc2bcc21" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ad86ab25-92ec-4e3e-96c1-3ac9fc2bcc21")) {                    Plotly.newPlot(                        "ad86ab25-92ec-4e3e-96c1-3ac9fc2bcc21",                        [{"x":["approaching","programming","conjunction","discussion","approximator","connecting","possibility","increases","benchmark","explorationexploitation","progressively","complexity","empirically","experiments","outperforms","strategies","instabilities","significantly","phenomenon","reinforcement","approximate","efficient","counterfactual","answering","probabilistic","sequential","interested","particular","predictions","interventions","algorithm","posterior","components","complementary","substitutes","complements","inference","interpretable","selecting","selection","coordinate","synthetic","naturally","classifying","expressed","maximizing","regularized","informative","classification","probability","validation","likelihood","subgroups","regression","conditioned","minimizing","generalized","predicting","estimated","performance","techniques","implement","presented","preprocessing","standalone","important","redundancy","providing","approaches","uncertainty","flexibility","parametric","exploration","distribution","representation","generalizes","demonstrate","converges","illustrate","optimistically","favorably","assessment","specifically","asymptotic","parameters","decorrelated","distributions","alternatives","developed","misspecification","construct","theoretical","statistic","inferential","furthermore","guarantees","confidence","individual","dimensional","penalized","generalize","perspective","numerical","conducted","introducing","framework","exponentially","characterize","functions","applicable","establish","hypothesis","estimators","applications","experience","effectiveness","component","critically","detection","extensive","evaluation","investigate","supervision","observation","supervised","methodology","deficiencies","recursively","successful","predicted","transition","successes","recursive","dynamically","differentiable","prediction","aggregating","stochastic","environments","structured","constructs","different","combining","optimised","outperform","promising","auxiliary","challenges","replacement","especially","chebyshev","therefore","approximation","instances","interests","recurrence","designing","multiplicative","developing","principal","construction","polynomials","polynomial","independent","iterative","otherwise","described","difficult","describes","optimization","effective","situations","diversity","objective","classifiers","objectives","neighbour","unavailable","imprecise","optimizing","classifies","accurately","eigenvectors","unsupervised","reduction","management","identification","transform","identifies","signature","incremental","signatures","frequency","dimensionality","clustering","embedding","recognition","automated","decompose","reseeding"],"y":[5,132,20,35,2,14,32,54,212,3,13,228,79,595,249,92,2,242,20,140,128,411,3,50,164,71,20,274,86,6,824,42,114,31,1,3,211,30,45,159,19,127,48,34,32,26,45,38,511,177,49,58,4,105,29,47,65,68,63,878,372,82,192,20,4,353,20,80,460,95,36,50,52,233,359,40,542,24,70,3,16,40,147,23,229,1,114,28,202,1,84,158,9,4,161,86,50,127,181,5,50,51,85,63,51,557,29,44,220,64,40,59,15,431,37,217,105,11,327,164,261,126,48,65,191,62,8,14,85,40,32,12,31,32,23,226,14,129,94,98,20,729,106,4,98,103,21,115,8,114,0,150,135,102,15,5,38,11,54,34,56,14,62,137,62,17,59,157,82,297,225,40,50,155,104,25,4,7,3,50,12,59,3,162,97,48,106,71,19,15,29,7,49,58,146,124,368,99,18,0],"type":"bar"},{"x":["approaching","programming","conjunction","discussion","approximator","connecting","po ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4506,), (4506, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8025

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Unsupervised</span> <span style='background-color:rgba(0, 255, 0, 0.5199999999999999);'>Induction</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Contingent</span> <span style=''>Event</span> <span style=''>Pairs</span> <span style=''>from</span> <span style=''>Film</span> <span style=''>Scenes</span> <br/><br/><span style=''>Human</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555556);'>engagement</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>narrative</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partially</span> <span style=''>driven</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.7054263565891472);'>reasoning</span> <span style=''>about</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>discourse</span> <span style='background-color:rgba(0, 255, 0, 0.4453781512605042);'>relations</span> <span style=''>between</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>narrative</span> <span style=''>events</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expectations</span> <span style=''>about</span> <span style=''>what</span> <span style=''>is</span> <span style=''>likely</span> <span style=''>to</span> <span style=''>happen</span> <span style=''>next</span> <span style=''>that</span> <span style=''>results</span> <span style=''>from</span> <span style=''>such</span> <span style='background-color:rgba(0, 255, 0, 0.7054263565891472);'>reasoning</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333326);'>Researchers</span> <span style=''>in</span> <span style=''>NLP</span> <span style=''>have</span> <span style=''>tackled</span> <span style=''>modeling</span> <span style=''>such</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expectations</span> <span style=''>from</span> <span style=''>a</span> <span style=''>range</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>perspectives</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style=''>treating</span> <span style=''>it</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.31493506493506485);'>inference</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contingent</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>discourse</span> <span style=''>relation</span> <span style=''>or</span> <span style=''>as</span> <span style=''>a</span> <span style=''>type</span> <span style=''>of</span> <span style=''>common</span> <span style=''>sense</span> <span style=''>causal</span> <span style='background-color:rgba(0, 255, 0, 0.7054263565891472);'>reasoning</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>to</span> <span style=''>model</span> <span style='background-color:rgba(255, 0, 0, 0.5433070866141733);'>likelihood</span> <span style=''>between</span> <span style=''>events</span> <span style=''>by</span> <span style=''>drawing</span> <span style=''>on</span> <span style=''>several</span> <span style=''>of</span> <span style=''>these</span> <span style=''>lines</span> <span style=''>of</span> <span style=''>previous</span> <span style=''>work</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implement</span> <span style=''>and</span> <span style=''>evaluate</span> <span style='background-color:rgba(0, 255, 0, 0.3278688524590165);'>different</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unsupervised</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>event</span> <span style=''>pairs</span> <span style=''>that</span> <span styl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Simulated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Annealing</span> <span style=''>Rigorous</span> <span style=''>finite</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guarantees</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>domains</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Simulated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>annealing</span> <span style=''>is</span> <span style=''>a</span> <span style=''>popular</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaching</span> <span style=''>the</span> <span style=''>solution</span> <span style=''>of</span> <span style=''>a</span> <span style=''>global</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>Existing</span> <span style=''>results</span> <span style=''>on</span> <span style=''>its</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>apply</span> <span style=''>to</span> <span style=''>discrete</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combinatorial</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>where</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>can</span> <span style=''>assume</span> <span style=''>only</span> <span style=''>a</span> <span style=''>finite</span> <span style=''>set</span> <span style=''>of</span> <span style=''>possible</span> <span style=''>values</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>new</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulation</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>annealing</span> <span style=''>which</span> <span style=''>allows</span> <span style=''>one</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guarantee</span> <span style=''>finite</span> <span style=''>time</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>The</span> <span style=''>results</span> <span style=''>hold</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>universally</span> <span style=''>for</span> <span style=''>any</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>on</span> <span style=''>a</span> <span style=''>bounded</span> <span style=''>domain</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>establish</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connection</span> <span style=''>between</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>annealing</span> <span style=''>and</span> <span style=''>up</span> <span style=''>to</span> <span style=''>date</span> <span style=''>theory</span> <span style ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Gradient</span> <span style=''>Descent</span> <span style=''>Learns</span> <span style=''>Linear</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>Dynamical</span> <span style=''>Systems</span> <br/><br/><span style=''>We</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>gradient</span> <span style=''>descent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiently</span> <span style='background-color:rgba(255, 0, 0, 0.3513513513513513);'>converges</span> <span style=''>to</span> <span style=''>the</span> <span style=''>global</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimizer</span> <span style=''>of</span> <span style=''>the</span> <span style=''>maximum</span> <span style='background-color:rgba(255, 0, 0, 0.5433070866141733);'>likelihood</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>of</span> <span style=''>an</span> <span style=''>unknown</span> <span style=''>linear</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>invariant</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>dynamical</span> <span style=''>system</span> <span style=''>from</span> <span style=''>a</span> <span style=''>sequence</span> <span style=''>of</span> <span style=''>noisy</span> <span style='background-color:rgba(255, 0, 0, 0.3744493392070485);'>observations</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generated</span> <span style=''>by</span> <span style=''>the</span> <span style=''>system</span> <span style=''>Even</span> <span style=''>though</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>function</span> <span style=''>is</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>we</span> <span style=''>provide</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style=''>running</span> <span style=''>time</span> <span style=''>and</span> <span style=''>sample</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>bounds</span> <span style=''>under</span> <span style=''>strong</span> <span style=''>but</span> <span style=''>natural</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assumptions</span> <span style=''>Linear</span> <span style=''>systems</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identification</span> <span style=''>has</span> <span style=''>been</span> <span style=''>studied</span> <span style=''>for</span> <span style=''>many</span> <span style=''>decades</span> <span style=''>yet</span> <span style=''>to</span> <span style=''>the</span> <span style=''>best</span> <span style=''>of</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.35573122529644274);'>knowledge</span> <span style=''>these</span> <span style=''>are</span> <span style=''>the</span> <span style=''>first</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>polynomial</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantees</span> <span style=''>for</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>we</span> <span style=''>consider</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Loss</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Functions</span> <span style=''>for</span> <span style=''>Top</span> <span style=''>k</span> <span style=''>Error</span> <span style=''>Analysis</span> <span style=''>and</span> <span style=''>Insights</span> <br/><br/><span style=''>In</span> <span style=''>order</span> <span style=''>to</span> <span style=''>push</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>realistic</span> <span style=''>computer</span> <span style=''>vision</span> <span style=''>tasks</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>classes</span> <span style=''>in</span> <span style=''>modern</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>benchmark</span> <span style=''>datasets</span> <span style=''>has</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significantly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increased</span> <span style=''>in</span> <span style=''>recent</span> <span style=''>years</span> <span style=''>This</span> <span style=''>increase</span> <span style=''>in</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>classes</span> <span style=''>comes</span> <span style=''>along</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increased</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>ambiguity</span> <span style=''>between</span> <span style=''>the</span> <span style=''>class</span> <span style=''>labels</span> <span style=''>raising</span> <span style=''>the</span> <span style=''>question</span> <span style=''>if</span> <span style=''>top</span> <span style=''>1</span> <span style=''>error</span> <span style=''>is</span> <span style=''>the</span> <span style=''>right</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>measure</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>provide</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extensive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparison</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evaluation</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>established</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multiclass</span> <span style=''>methods</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>comparing</span> <span style=''>their</span> <span style=''>top</span> <span style=''>k</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>both</span> <span style=''>from</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>from</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>perspective</span> <span style=''>Moreover</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>novel</span> <span style=''>top</span> <span style=''>k</span> <span style=''>loss</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>modifications</span> <span style=''>of</span> <span style=''>the</span> <span style=''>softmax</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multiclass</span> <span style=''>SVM</span> <span style=''>losses</span> <sp ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.09294871794871795)
# 	representation (0.12784900284900286)
# 	segmentation (0.06267806267806268)
# 	information (0.23646723646723647)
# 	architecture (0.08653846153846154)
# 	experimental (0.1388888888888889)
# 	detection (0.11645299145299146)
# 	different (0.25961538461538464)
# 	convolutional (0.12962962962962962)
# 	recognition (0.13105413105413105)
#
# Some Statistics words are:
# 	convergence (0.12198795180722892)
# 	theoretical (0.14558232931726908)
# 	stochastic (0.1390562248995984)
# 	estimation (0.17269076305220885)
# 	distribution (0.1852409638554217)
# 	algorithm (0.40160642570281124)
# 	statistical (0.16516064257028112)
# 	dimensional (0.18373493975903615)
# 	inference (0.2033132530120482)
# 	regression (0.18022088353413654)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="993f91be-b07c-4100-9c7b-8b996220c955" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("993f91be-b07c-4100-9c7b-8b996220c955")) {                    Plotly.newPlot(                        "993f91be-b07c-4100-9c7b-8b996220c955",                        [{"x":["approaching","programming","conjunction","discussion","approximator","connecting","possibility","increases","benchmark","explorationexploitation","progressively","complexity","empirically","experiments","outperforms","strategies","instabilities","significantly","phenomenon","reinforcement","approximate","efficient","counterfactual","answering","probabilistic","sequential","interested","particular","predictions","interventions","algorithm","posterior","components","complementary","substitutes","complements","inference","interpretable","selecting","selection","coordinate","synthetic","naturally","classifying","expressed","maximizing","regularized","informative","classification","probability","validation","likelihood","subgroups","regression","conditioned","minimizing","generalized","predicting","estimated","performance","techniques","implement","presented","preprocessing","standalone","important","redundancy","providing","approaches","uncertainty","flexibility","parametric","exploration","distribution","representation","generalizes","demonstrate","converges","illustrate","optimistically","favorably","assessment","specifically","asymptotic","parameters","decorrelated","distributions","alternatives","developed","misspecification","construct","theoretical","statistic","inferential","furthermore","guarantees","confidence","individual","dimensional","penalized","generalize","perspective","numerical","conducted","introducing","framework","exponentially","characterize","functions","applicable","establish","hypothesis","estimators","applications","experience","effectiveness","component","critically","detection","extensive","evaluation","investigate","supervision","observation","supervised","methodology","deficiencies","recursively","successful","predicted","transition","successes","recursive","dynamically","differentiable","prediction","aggregating","stochastic","environments","structured","constructs","different","combining","optimised","outperform","promising","auxiliary","challenges","replacement","especially","chebyshev","therefore","approximation","instances","interests","recurrence","designing","multiplicative","developing","principal","construction","polynomials","polynomial","independent","iterative","otherwise","described","difficult","describes","optimization","effective","situations","diversity","objective","classifiers","objectives","neighbour","unavailable","imprecise","optimizing","classifies","accurately","eigenvectors","unsupervised","reduction","management","identification","transform","identifies","signature","incremental","signatures","frequency","dimensionality","clustering","embedding","recognition","automated","decompose","reseeding","hospitals","underlying","populations","covariance","motivated","formulation","structure","relationships","institutional","hierarchical","information","collected","complications","dependence","appropriately","differences","properties","improvement","equiangular","separation","observations","typically","depending","characterized","approximating","denoising","iteratively","factorization","application","computing","dictionaries","established","coherence","dictionary","interacting","discovery","interactive","institution","composite","artifacts","including","automatically","behaviours","financial","correlated","development","highlight","collection","implemented","evaluated","representing","quantifying","processes","interaction","interactions","vis ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	chebyshev
# 	reseeding
# 	equiangular
# 	advertiser
# 	multistage
# 	econometrics
# 	laplacians
# 	disregard
# 	sequentialized
# 	inverting
# 	nonparametrics
# 	covariances
# 	laborious
# 	measurable
# 	measurability
# 	changepoints
# 	seasonality
# 	reparametrizations
# 	reparametrization
# 	functionals
# Some words which never appear in Statistics papers:
# 	optimistically
# 	institution
# 	reachability
# 	concurrent
# 	keypoints
# 	electrode
# 	accomplishing
# 	cooperatively
# 	intuitionistic
# 	cambridge
# 	portuguese
# 	concatenation
# 	identifier
# 	reordering
# 	infrastructures
# 	bilingual
# 	monolingual
# 	paraphrase
# 	judgement
# 	paraphrases

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.068802553243724e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.76
